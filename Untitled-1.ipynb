# %%
# !git clone https://github.com/ahmed-f-elaswar/math-content-recognition-.git
# Out:
# Cloning into 'math-content-recognition-'...
# remote: Enumerating objects: 10440, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 10440 (delta 0), reused 0 (delta 0), pack-reused 10439 (from 2)
# Receiving objects: 100% (10440/10440), 75.02 MiB | 11.79 MiB/s, done.
# Resolving deltas: 100% (182/182), done.
