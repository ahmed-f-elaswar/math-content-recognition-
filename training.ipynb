# %%
# %cd /kaggle/working
# !git clone https://github.com/ahmed-f-elaswar/math-content-recognition-
# %cd math-content-recognition-

# %%
# !pip install texTeller --no-deps
# !pip install texTeller[train] --no-deps
# !pip install --no-cache-dir \
    transformers==4.38.2 \
    datasets==2.18.0 \
    accelerate \
    augraphy \
    python-dotenv \
    einops \
    pillow \
    tensorboard

# %%
# !python examples/train_texteler/train.py
